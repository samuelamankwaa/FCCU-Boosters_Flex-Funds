# %%
import pandas as pd
import numpy as np
import pyodbc

pd.set_option('display.max_rows', None)
cnxn = pyodbc.connect('DRIVER={SQL Server};\
                      SERVER=DXPLORE;\
                      DATABASE=DataMart')
df1 = pd.read_sql_query('SELECT * FROM [DataMart].[FCCU].[Subscription_Payroll_Enrollment_Snapshot]', cnxn)
df2 = pd.read_sql_query('SELECT * FROM [DataMart].[FCCU].[Subscription_Payroll_Enrollment]', cnxn)
df1['CurrentAdvAmt'] = df1['CurrentAdvAmt'].astype('object')
df2['CurrentAdvAmt'] = df2['CurrentAdvAmt'].astype('object')
res = (df2.merge(df1, on=['Member_No','Individual_Id','Status','Enroll_Date','Current_Advance_Date','CurrentAdvAmt','Restricted','Unenroll_Date','Company_Name'], how='outer', indicator=True)
      .query('_merge != "both"')
      .drop('_merge', 1))
#res
Final = df2.merge(res, on= ['Member_No','Individual_Id','Status','Enroll_Date','Current_Advance_Date','CurrentAdvAmt','Restricted','Unenroll_Date','Company_Name'], how = 'inner')
Final = Final[['id','Member_No','Individual_Id','Status','Enroll_Date','Current_Advance_Date','CurrentAdvAmt','Restricted','Unenroll_Date','Company_Name']]
df_all = pd.concat([df1.set_index('id'), Final.set_index('id')], 
                   axis='columns', keys=['Before', 'After'])
df_final = df_all.swaplevel(axis='columns')[Final.columns[1:]]
pd.set_option('display.max_columns',None)
Final2 = df_final.merge(Final, on= ['id'], how ='inner')
Final2.drop(['Member_No','Individual_Id','Status','Enroll_Date','Current_Advance_Date','CurrentAdvAmt','Restricted','Unenroll_Date','Company_Name'], axis=1, inplace=True)
Final2['Run_date'] = pd.to_datetime('today')
Final2.columns = ['id','Member_No_Before','Member_No_After','Individual_Id_Before','Individual_Id_After','Status_Before','Status_After','Enroll_Date_Before','Enroll_Date_After','Current_Advance_Date_Before','Current_Advance_Date_After','CurrentAdvAmt_Before','CurrentAdvAmt_After','Restricted_Before','Restricted_After','Unenroll_Date_Before','Unenroll_Date_After','Company_Name_Before','Company_Name_After','Run_date']
Final2
#Final2.to_excel('Flexfunds.xlsx', engine='openpyxl')
# Out:
# C:\Users\SAMUEL~1.AMA\AppData\Local\Temp/ipykernel_18416/4194708462.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   res = (df2.merge(df1, on=['Member_No','Individual_Id','Status','Enroll_Date','Current_Advance_Date','CurrentAdvAmt','Restricted','Unenroll_Date','Company_Name'], how='outer', indicator=True)
# C:\Users\samuel.amankwaa\Anaconda3\lib\site-packages\pandas\core\frame.py:9190: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left,1 on the right)
#   return merge(
#     id  Member_No_Before  Member_No_After  Individual_Id_Before  \
# 0  361         3861400.0        3861400.0              569159.0
# 1  370         2583020.0        2583020.0              434944.0
# 2  378               NaN        4019770.0                   NaN
# 3  379               NaN        1838680.0                   NaN
#
# ...

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("mssql+pyodbc://<samuel.amankwaa>:<KwadwoMulivah@1>@<dxplore><DataMart>")

# %%
Final2.to_sql("[Subscription_Payroll_Enrollment_Snapshot]", engine)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
# ...

# %%
Final2.to_excel('Flexfunds1.xlsx', engine='openpyxl')

# %%
pwd
# Out:
# 'C:\\Users\\samuel.amankwaa'
